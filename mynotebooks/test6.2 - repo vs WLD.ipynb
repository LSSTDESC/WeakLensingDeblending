# %%
import numpy as np 
from subprocess import Popen, PIPE, STDOUT
import os
import matplotlib.pyplot as plt
import galsim
import copy

# %%
# %pylab inline
from astropy.table import Table
import fitsio
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['f', 'copy', 'std', 'diff']
# `%matplotlib` prevents importing * from pylab and numpy

# %%
#directories that would be using 
WLD = '/Users/Ismael/code/lensing/WeakLensingDeblending/'
repo = '/Users/Ismael/code/lensing/repo/'

# %%
os.chdir(WLD)
width = 512 
height = 512
psf_beta = 3.0 
psf_e1 = 0. #when it is 0 then the sigma matches the fwhm. 
psf_e2 = 0. 
psf_fwhm = .7
airmass = 1.
# pixel_scale = .2
# truncate_radius = 30. 
# min_snr = .05
cd = 1.06502 #disk. 
cb = 10.8396 #bulge

# %%
#produces demo.fits file with partials, 
cmd = ('./simulate.py --catalog-name OneDegSq.fits --image-width {0} --image-height {1} \
--survey-name LSST --filter-band i --output-name demo --verbose --calculate_bias \
--mirror-diameter 0 --atmospheric-psf-beta {2} --atmospheric-psf-e1 {3} --atmospheric-psf-e2 {4} \
--zenith-psf-fwhm {5} --no-bulge --no-agn --airmass {6} --only-id 402700632300 --verbose-model').format(width,height,psf_beta,psf_e1,psf_e2,psf_fwhm,airmass)
p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
output = p.stdout.read()
print cmd
print output
# Out:
# ./simulate.py --catalog-name OneDegSq.fits --image-width 512 --image-height 512 --survey-name LSST --filter-band i --output-name demo --verbose --calculate_bias --mirror-diameter 0 --atmospheric-psf-beta 3.0 --atmospheric-psf-e1 0.0 --atmospheric-psf-e2 0.0 --zenith-psf-fwhm 0.7 --no-bulge --no-agn --airmass 1.0 --only-id 402700632300 --verbose-model
# /Users/Ismael/miniconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Read 858502 catalog entries from OneDegSq.fits
# Simulating LSST i-band survey with {'exposure_time': 6900.0, 'sky_brightness': 20.0, 'mirror_diameter': 0.0, 'airmass': 1.0, 'zero_point': 41.5, 'survey_name': 'LSST', 'image_width': 512, 'filter_band': 'i', 'pixel_scale': 0.2, 'atmospheric_psf_beta': 3.0, 'cosmic_shear_g2': 0.0, 'zenith_psf_fwhm': 0.7, 'image_height': 512, 'effective_area': 33.212, 'extinction': 0.07, 'atmospheric_psf_e1': 0.0, 'cosmic_shear_g1': 0.0, 'atmospheric_psf_e2': 0.0} (obs.frac. = 0.000)
# Will render all pixels with at least 33.8 detected electrons.
# PSF dilution factor is 0.051823.
# Simulation output will be saved to demo.fits
# a_d,b_d: 1.12353277206,0.299915492535
# Building galaxy model for id=402700632300 with z=1.385
# flux = 1.1e+06 detected electrons (i-band AB = 22.5)
# centroid at (-15.955495,22.433760) arcsec relative to image center, beta = 1.442695 rad
#  disk: frac = 0.956773, hlr = 0.580487 arcsec, q = 0.266940
# identifier 402700632300
# disk_q 0.266939692364
# disk_hlr_arcsecs 0.58048676532
# bulge_hlr_acsecs None
# beta_radians 1.44269468309
# disk_flux 1049961.07539
# self.cosmic_shear_g1 0.0
# self.cosmic_shear_g2 0.0
# a1: 1.42162154126
# b1: 0.379487216882
# sqrt(a1*b1) = hlr_d?: 0.734497925219
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# mean_sky_level 455991.953152
# galsim.Image(bounds=galsim.BoundsI(165,187,344,392), scale=0.2)
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(0.0111714666886,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.122161866645,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.13333333333333333, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(0.0778381333553,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': -0.13333333333333333, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.188828533311,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(0.0111714666886,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(0.0111714666886,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.122161866645,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.122161866645,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.05, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.566809088515,0.188762403497,0.188762403497,2.00796223638).shift(0.0111714666886,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': -0.05, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.512827270562,0.170785031735,0.170785031735,1.81672773767).shift(0.0111714666886,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.05, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.566809088515,0.188762403497,0.188762403497,2.00796223638).shift(-0.122161866645,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': -0.05, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.512827270562,0.170785031735,0.170785031735,1.81672773767).shift(-0.122161866645,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.556263099667,0.185250310549,0.174459030323,1.85580993987).shift(0.0111714666886,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.523859423958,0.174459030323,0.185250310549,1.97060230729).shift(0.0111714666886,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.556263099667,0.185250310549,0.174459030323,1.85580993987).shift(-0.122161866645,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.523859423958,0.174459030323,0.185250310549,1.97060230729).shift(-0.122161866645,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.545456901925,0.237250854143,0.19605650829,1.91860176369).shift(0.0111714666886,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.534665621699,0.122458486729,0.163652832582,1.90781048347).shift(0.0111714666886,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.545456901925,0.237250854143,0.19605650829,1.91860176369).shift(-0.122161866645,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': -0.06666666666666667, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.534665621699,0.122458486729,0.163652832582,1.90781048347).shift(-0.122161866645,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.13333333333333333}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,0.0670931642413), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': -0.13333333333333333}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.199573502425), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.05, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.566809088515,0.188762403497,0.188762403497,2.00796223638).shift(-0.055495199978,0.000426497574669) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': -0.05, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.512827270562,0.170785031735,0.170785031735,1.81672773767).shift(-0.055495199978,0.000426497574669) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.05, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.566809088515,0.188762403497,0.188762403497,2.00796223638).shift(-0.055495199978,-0.132906835759) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': -0.05, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.512827270562,0.170785031735,0.170785031735,1.81672773767).shift(-0.055495199978,-0.132906835759) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.556263099667,0.185250310549,0.174459030323,1.85580993987).shift(-0.055495199978,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.523859423958,0.174459030323,0.185250310549,1.97060230729).shift(-0.055495199978,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': 0.0, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.556263099667,0.185250310549,0.174459030323,1.85580993987).shift(-0.055495199978,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': 0.0, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.523859423958,0.174459030323,0.185250310549,1.97060230729).shift(-0.055495199978,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.545456901925,0.237250854143,0.19605650829,1.91860176369).shift(-0.055495199978,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.534665621699,0.122458486729,0.163652832582,1.90781048347).shift(-0.055495199978,0.000426497574669), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.545456901925,0.237250854143,0.19605650829,1.91860176369).shift(-0.055495199978,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': -0.06666666666666667}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.534665621699,0.122458486729,0.163652832582,1.90781048347).shift(-0.055495199978,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.566809088515,0.188762403497,0.188762403497,2.00796223638).shift(-0.055495199978,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': -0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.512827270562,0.170785031735,0.170785031735,1.81672773767).shift(-0.055495199978,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.1, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.593799997492,0.197751089377,0.197751089377,2.10357948573).shift(-0.055495199978,-0.066240169092) * 0.826446280992, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': -0.1, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.485836361585,0.161796345854,0.161796345854,1.72111048832).shift(-0.055495199978,-0.066240169092) * 1.23456790123, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': 0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.58407625465,0.194512826076,0.183181981839,1.94860043687).shift(-0.055495199978,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': 0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.550052395156,0.183181981839,0.194512826076,2.06913242265).shift(-0.055495199978,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': -0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.528449944683,0.175987795022,0.165736078807,1.76301944288).shift(-0.055495199978,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': -0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.49766645276,0.165736078807,0.175987795022,1.87207219192).shift(-0.055495199978,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': 0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.572729747022,0.249113396851,0.205859333705,2.01453185188).shift(-0.055495199978,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': 0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.561398902784,0.128581411065,0.171835474211,2.00320100764).shift(-0.055495199978,-0.066240169092) * 0.907029478458, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': -0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.518184056829,0.225388311436,0.186253682876,1.82267167551).shift(-0.055495199978,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': -0.05, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.507932340614,0.116335562392,0.155470190952,1.81241995929).shift(-0.055495199978,-0.066240169092) * 1.108033241, galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.556263099667,0.185250310549,0.174459030323,1.85580993987).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.523859423958,0.174459030323,0.185250310549,1.97060230729).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.06, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.573240032694,0.190904077835,0.169292295439,1.80084873817).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': -0.06, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.508344934653,0.169292295439,0.190904077835,2.03074432177).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.561911884929,0.242755857431,0.190746800916,1.86204444375).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.551115740966,0.127911751961,0.15832852055,1.85124829979).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': -0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.529493604563,0.231959713468,0.201542944879,1.97688854922).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': -0.03, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.5186974606,0.117115607998,0.169124664513,1.96609240526).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.545456901925,0.237250854143,0.19605650829,1.91860176369).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.03, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.534665621699,0.122458486729,0.163652832582,1.90781048347).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.06, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.551598374872,0.295045978435,0.212545735658,1.92660242117).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': -0.06, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).transform(0.529986592475,0.065150394839,0.147650637617,1.90499063877).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# {'dg2': 0.0, 'dg1': 0.0, 'ds': 0.0, 'dx': 0.0, 'dy': 0.0}
# galsim.Convolve((galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656))).shear(galsim.Shear(g1=-0.559720831877,g2=0.146624596656)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845))
# Simulated 1 galaxies in 1 overlap groups.

# %%
catalog = Table.read('demo.fits', hdu=1)
fits = fitsio.FITS('demo.fits')

# %%
#example particular columns and conditions out of the fits file. 
print catalog.colnames
selected = ((catalog['grp_size'] == 1) & (catalog['snr_grpf']>20) & (catalog['visible'] == 1))
selected_catalog = catalog[selected]
selected_catalog
# Out:
# ['db_id', 'grp_id', 'grp_size', 'grp_rank', 'visible', 'xmin', 'xmax', 'ymin', 'ymax', 'f_disk', 'f_bulge', 'dx', 'dy', 'z', 'ab_mag', 'ri_color', 'flux', 'sigma_m', 'sigma_p', 'e1', 'e2', 'a', 'b', 'beta', 'psf_sigm', 'purity', 'snr_sky', 'snr_iso', 'snr_grp', 'snr_isof', 'snr_grpf', 'ds', 'dg1', 'dg2', 'ds_grp', 'dg1_grp', 'dg2_grp', 'hsm_sigm', 'hsm_e1', 'hsm_e2', 'g1_fit', 'g2_fit']
# <Table length=1>
#    db_id        grp_id    grp_size grp_rank ...  hsm_e1  hsm_e2  g1_fit  g2_fit
#    int64        int64      int16    int16   ... float32 float32 float32 float32
# ------------ ------------ -------- -------- ... ------- ------- ------- -------
# 402700632300 402700632300        1        0 ...     nan     nan     0.0     0.0

# %% [markdown]
# ### Manual checking by entries by forcing what I think are the correct values (look at table above)

# %%
import math 
os.chdir(repo)
import galfun
import fisher

# %%
# a = 0.945682
# b = 0.25244
#all gotten from the table except a_d, b_d, disk_hlr_arcsecs
galaxy_id = 402700632300
e1 = -0.559721 #in David's this is g1,g2 of Galsim. 
e2 = 0.146625
# e1=0.
# e2=0.
x0 = -0.055495199978
y0 = -0.066240169092
disk_hlr_arcsecs = 0.58048676532 #sqrt(a_d*b_d) 
flux = 1049961.07539
snr = 117.066 ## snr_sky
project_name = 'project15'
os.chdir(WLD)
cmd = './fisher.py --i demo.fits -o notebooks/example.png --galaxy {0} --label-color white --no-display --bias --covariance'.format(galaxy_id)
p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
output = p.stdout.read()
print 'galaxy {0}:'.format(galaxy_id) 
print 'WLD:'
print output
print
os.chdir(repo)
cmd = ('python generate.py -p {0} -gal 1 --psf_model psf_moffat --galaxy-model exponential --g1 {1} --g2 {2} --y0 {3} --x0 {4} '
        '--flux {5} --psf_flux 1. --hlr {6} --psf_fwhm {7} --snr {8} --psf_beta {9}').format(
        project_name,e1,e2,y0,x0,flux,disk_hlr_arcsecs,psf_fwhm,snr,psf_beta)
p = Popen(cmd, shell=True, stdin=PIPE, stdout=PIPE, stderr=STDOUT, close_fds=True)
output = p.stdout.read()
print output
array_d = fits[2].read()[0]
stamp = galsim.Image(array=array_d,scale=.2) 
g_parameters = galfun.GParameters(project_name)
image_renderer = galfun.ImageRenderer(stamp=stamp)
fish = fisher.Fisher(g_parameters=g_parameters,image_renderer=image_renderer, snr=float(snr))
print 'repo:'
for param in fish.biases:
    std = math.sqrt(fish.covariance_matrix[param,param])
    bias = fish.biases[param]
    print param
    print 'value: {0}'.format(g_parameters.params[param])
    print 'std: {0}'.format(std)
    print 'bias: {0}'.format(bias)
    print 'bias/std: {0}'.format(bias/std)
print
# Out:
# galaxy 402700632300:
# WLD:
# /Users/Ismael/miniconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# flux
# std: 14282.1765081
# bias: 179.348438284
# bias/std: 0.0125575004749
# x
# std: 0.00576126793245
# bias: 7.66723022045e-10
# bias/std: 1.33082340734e-07
# y
# std: 0.0116551954687
# bias: -5.11655840805e-09
# bias/std: -4.38993787945e-07
# s
# std: 0.0232631065887
# bias: -0.000471679253146
# bias/std: -0.0202758497171
# g1
# std: 0.0205154428122
# bias: -0.000624405725571
# bias/std: -0.0304358882861
# g2
# std: 0.0104945368142
# bias: 0.000163657972176
# bias/std: 0.0155945874577
#
#
#
# x0_1
# 0.0666666666667
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(0.0111714666887,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.122161866645,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# y0_1
# 0.0666666666667
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,0.000426497574667), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,-0.132906835759), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# flux_1
# 10499.6107539
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1060460.68614).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1039461.46464).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# hlr_1
# 0.029024338266
# (galsim.Convolve(galsim.Exponential(scale_radius=0.363161555514, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# (galsim.Convolve(galsim.Exponential(scale_radius=0.328574740703, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# g1_1
# 0.03
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.529721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.589721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# g2_1
# 0.03
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.176625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.116625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# repo:
# hlr_1
# value: 0.58048676532
# std: 0.0134302246202
# bias: -0.000271955545713
# bias/std: -0.0202495158051
# g2_1
# value: 0.146625
# std: 0.0125019071885
# bias: 4.81661355372e-05
# bias/std: 0.00385270301651
# g1_1
# value: -0.559721
# std: 0.0138605346673
# bias: -0.000183634321226
# bias/std: -0.0132487184394
# x0_1
# value: -0.055495199978
# std: 0.00571990682447
# bias: -5.02937818931e-09
# bias/std: -8.79276244116e-07
# flux_1
# value: 1049961.07539
# std: 14222.9332243
# bias: 178.686913947
# bias/std: 0.0125632955684
# y0_1
# value: -0.066240169092
# std: 0.011566982214
# bias: -1.21171040276e-08
# bias/std: -1.04755966625e-06

# %%
plt.figure()
plt.imshow(array_d)
plt.figure()
plt.imshow(fish.image.array)

# %%
# # I am now going to do a pixel by pixel comparison to figure out differences. 
# entry = 0 
# #find corresponding entry 
# for i,elem in enumerate(fits[1]):
#     if elem[0] == 402700632300: 
#         entry = i
#         for j,e in enumerate(elem): 
#             print catalog.colnames[j]+ ': ' + str(e)
# print
# print entry

# %%
#compare histograms of both images, this is the one in the datacube 
img_wld = fits[2].read()[0]
plt.figure()
print img_wld.min() 
print img_wld.max()
print sum(img_wld)
print img_wld.shape
_ = plt.hist(img_wld.flatten(),np.linspace(img_wld.min(),img_wld.max(),num=100))
plt.figure()
plt.imshow(img_wld)
plt.colorbar()
# Out:
# 0.0
# 14529.4853516
# 1039737.76315
# (49, 23)

# %%
f = fish.image.array
print fish.model
plt.figure()
print f.min()
print f.max()
print f.shape
print f.sum()
_ = plt.hist(f.flatten(),np.linspace(f.min(),f.max(),num=100))
plt.figure()
plt.imshow(f)
plt.colorbar()
# Out:
# (galsim.Convolve(galsim.Exponential(scale_radius=0.345868148108, flux=1049961.07539).shear(galsim.Shear(g1=-0.559721,g2=0.146625)).shift(-0.055495199978,-0.066240169092), galsim.Moffat(beta=3.0, scale_radius=0.686510711845)))
# 0.624916726047
# 14529.4840873
# (49, 23)
# 1044285.4277

# %%
plt.figure()
diff = img_wld - f
print diff.max()
print diff.min()
_ = plt.hist(diff.flatten(),np.linspace(diff.min(),diff.max(),num=100))
plt.figure()
plt.imshow(diff)
plt.colorbar()
# Out:
# 0.00599352001882
# -33.655407849

# %%
import pickle 
#use pickled wld image 
os.chdir(WLD)
model_p = (pickle.load(open("model.p","rb"))).array
galaxy_model_p = (pickle.load(open("galaxy_model.p","rb"))).array
galaxy_profile_p = (pickle.load(open("galaxy_profile.p","rb"))).array
psf_model_p = (pickle.load(open("psf_model.p","rb"))).array 
final_p = (pickle.load(open("final.p","rb"))).array 
print 'model_p'
print model_p.shape
print model_p.max() 
print model_p.min()
plt.figure()
plt.imshow(model_p)
print 
print 'galaxy_profile_p'
print galaxy_profile_p.shape
print galaxy_profile_p.min()
print galaxy_profile_p.max() 
plt.figure()
plt.imshow(galaxy_profile_p)
print
print 'galaxy_model_p'
print galaxy_model_p.shape
print galaxy_model_p.min()
print galaxy_model_p.max()
plt.figure()
plt.imshow(galaxy_model_p)
print
print 'psf_model_p'
print psf_model_p.shape
print psf_model_p.min()
print psf_model_p.max()
plt.figure()
plt.imshow(psf_model_p)
print
print 'final_p'
print final_p.shape
print final_p.min()
print final_p.max()
print final_p.sum()
plt.figure()
plt.imshow(final_p)
print 
print 'datacube_image'
img_wld = fits[2].read()[0]
print img_wld.min()
print img_wld.max()
print img_wld.shape
plt.figure()
plt.imshow(img_wld)
# Out:
# model_p
# (19, 22)
# 14524.8
# 16.3981
#
# galaxy_profile_p
# (19, 22)
# 0.110113
# 33222.1
#
# galaxy_model_p
# (19, 22)
# -0.00130889
# 0.00147046
#
# psf_model_p
# (19, 22)
# 1.06246e-05
# 0.0488627
#
# final_p
# (301, 301)
# -0.00119027
# 14529.5
# 1.04996e+06
#
# datacube_image
# 0.0
# 14529.4853516
# (49, 23)

# %%
plt.figure()
plt.imshow(fits[2].read()[1])
plt.colorbar()
plt.figure()
plt.imshow(fish.derivatives_images['x0_1'])
plt.colorbar()
plt.figure()
plt.imshow(fits[2].read()[1] - fish.derivatives_images['x0_1'])
plt.colorbar()

# %%
fish.derivatives_images.keys()
# Out:
# ['hlr_1', 'g2_1', 'g1_1', 'x0_1', 'flux_1', 'y0_1']
